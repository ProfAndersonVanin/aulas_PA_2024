# %% [markdown]
# <a href="https://colab.research.google.com/github/ProfAndersonVanin/aulas_PA_2024/blob/main/Estruturas_Condicionais_e__La%C3%A7os_de_Repeticao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color='blue'>Condicionais</font>

# %% [markdown]
# ## Estruturas de condição
# ![image.png](data:image/png;base64,...)
# ####Estruturas de condição são artifícios das linguagens de programação para determinar qual bloco de código será executado a partir de uma determinada condição. No Python, assim como em outras linguagens, podemos trabalhar com as estruturas de condição utilizando o if/else como veremos abaixo.

# %% [markdown]
# **if/else**
#
# O if e o else são comandos que verificam determinada condição na programação.
#
# O uso do if em um programa em Python visa verificar se determinada ação é verdadeira e executar o bloco de código contido em seu escopo. Basicamente é feita da seguinte forma:

# %%
media = 7
if media > 6.9:
	print ("Você foi aprovado")
# Out:
# Você foi aprovado

# %% [markdown]
# No exemplo do código acima, utilizamos apenas o if para verificar se a variável media é maior que 6.9. Como esta condição é verdadeira, imprimimos a mensagem na tela “Você foi aprovado”. Caso esta condição fosse falsa, o código seguiria normalmente ignorando, desta forma, a linha 3, o nosso print.
#
# Já o uso o **if/else** fará com que uma das ações sejam executadas, já que se a condição dentro do if não for verdadeira, será executado o código contido no else. O if/else irá testar caso a condição seja verdadeira e executar uma determinada ação ou caso a mesma não seja executar outra.

# %% [markdown]
# ### Relembrando os operadores Lógicos e Relacionais

# %% [markdown]
# ### Operadores Relacionais
#
# Maior que      	         " > "
#
# Menor que 	             " <  "
#
# Igual a                  " == "
#
# Diferente de	           " !=  "
#
# Maior ou igual a	       "  >=  "
#
# Menor ou igual a	       "  <=  "

# %% [markdown]
# ### Operadores Lógicos
# AND
#
# OR
#
# NOT

# %% [markdown]
# # Vamos relacionar os operadores lógicos com os condicionais, vamos entender por meio do triangulo lógico
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Solicitando a entrada

# %%
a = float(input("Digite o primeiro lado do triangulo: "))
b = float(input("Digite o segundo lado do triangulo: "))
c = float(input("Digite o terceiro lado do triangulo: "))
# Out:
# Digite o primeiro lado do triangulo: 5
# Digite o segundo lado do triangulo: 3
# Digite o terceiro lado do triangulo: 1

# %% [markdown]
# # Verificando se é um **triangulo**

# %%
triangulo = ((a<b+c) and (b<a+c) and (c<a+b))
triangulo
# Out:
# False

# %%
print(("É um triângulo? ",triangulo))
# Out:
# ('É um triângulo? ', True)

# %% [markdown]
# # Verificando se é Equilatero: Todos os lados iguais

# %%
# and(triangulo))
equilatero = (a==b)and(b==c)
equilatero
# Out:
# False

# %%
print("Esse triângulo é equilatero? ", equilatero)
# Out:
# Esse triângulo é equilatero?  False

# %% [markdown]
# # Verificando de é Escaleno: Três lados Diferentes

# %%
# and (triangulo)
escaleno = (a!=b) and (a!=c) and (b!=c) and (triangulo)
escaleno
# Out:
# False

# %%
print("Esse triangulo é escaleno? ", escaleno)
# Out:
# Esse triangulo é escaleno?  False

# %% [markdown]
# # Verificando se é Isóceles: Dois Lados iguais

# %%
#usando o xou
isoceles = ((a==b) ^ (a==c) and (b!=c)) or ((b==c)^(b==a)) and (triangulo)
isoceles
# Out:
# False

# %%
#sem usar xou
# and (triangulo)
isoceles = ((a!=b) or (b!=c) or (a!=c)) and (triangulo)
isoceles
# Out:
# False

# %% [markdown]
# # Lógica da Execução do condicional

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Neste caso não estou verificando a habilitação apenas se tem 18 anos, caso não tenha não programei nada

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Fazer código

# %% [markdown]
# # Neste caso não estou verificando a habilitação apenas se tem 18 anos, caso não não vou deixar passar!!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Fazer Código

# %% [markdown]
# # Neste caso vamos verificar além da idade a habilitação, tem a carta de motorista?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Fazer Código

# %% [markdown]
# # Mais exemplos

# %%
media = 5.5
if media < 6.9:
	print ("Você foi reprovado")
else:
	print ("Você foi aprovado")
# Out:
# Você foi reprovado

# %%
# é possível incluit mais um argumento
if media < 5:
	print ("Você foi reprovado")
elif media > 5 and media < 7:
	print ("Você fará a recuperação")
else:
	print ("Você foi aprovado")
# Out:
# Você fará a recuperação

# %% [markdown]
# ### CUIDADOS COM IDENTAÇÃO NO PYTHON

# %%
#EXEMPLO ERRO

# %% [markdown]
# ### Exemplos

# %%
#usando operador relacional ==
concluiu = "sim"
entregou_ativ = "nao"
if (concluiu == "nao"):
  print("Você não receberá seu certificado")
else:
  print("Seu certificado será entre em Dezembro")
# Out:
# Seu certificado será entre em Dezembro

# %%
#usando operador lógico "OR"
if (concluiu == "nao") or (entregou_ativ == "nao"):
  print("Você não receberá seu certificado")
else:
  print("Seu certificado será entre em Dezembro")
# Out:
# Você não receberá seu certificado

# %%
#usando operador "!=", diferente
valor = 7
if (valor%2 != 0):
  print("Esse número é impar!")
else:
  print("Esse número é par!")
# Out:
# Esse número é impar!

# %%
#usando operador lógico "e"
idade = int(input("Qual sua idade: "))
resp = input("Carta Motorista ativa? Digite sim ou não")

if (idade >= 18) and (resp == "sim"):
  print("Você pode dirigir!!")
else:
  print("Você não pode dirigir")
# Out:
# Qual sua idade: 18
# Carta Motorista ativa? Digite sim ou nãosim
# Você pode dirigir!!

# %% [markdown]
# # Transformando o Triangulo Lógico em Condicional

# %%
# Aqui seu código
